# %%
# !pip install -U google-genai

# %%
import config
from google import genai

client = genai.Client(api_key=config.GEMINI_API_KEY)

response = client.models.generate_content(
    model=config.GEMINI_MODEL,
    contents="Write one sentence confirming that my Gemini API is working."
)

print(response.text)
# Out:
# Your Gemini API is working as expected.

# %%
pip install google-genai
# Out:
# Requirement already satisfied: google-genai in c:\users\svans\appdata\local\programs\python\python314\lib\site-packages (2.5.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\users\svans\appdata\local\programs\python\python314\lib\site-packages (from google-genai) (4.11.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.48.1 in c:\users\svans\appdata\local\programs\python\python314\lib\site-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.53.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\users\svans\appdata\local\programs\python\python314\lib\site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in c:\users\svans\appdata\local\programs\python\python314\lib\site-packages (from google-genai) (2.13.4)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\users\svans\appdata\local\programs\python\python314\lib\site-packages (from google-genai) (2.32.5)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in c:\users\svans\appdata\local\programs\python\python314\lib\site-packages (from google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in c:\users\svans\appdata\local\programs\python\python314\lib\site-packages (from google-genai) (16.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in c:\users\svans\appdata\local\programs\python\python314\lib\site-packages (from google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\svans\appdata\local\programs\python\python314\lib\site-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in c:\users\svans\appdata\local\programs\python\python314\lib\site-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in c:\users\svans\appdata\local\programs\python\python314\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.11)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\svans\appdata\local\programs\python\python314\lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\svans\appdata\local\programs\python\python314\lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (48.0.0)
# Requirement already satisfied: certifi in c:\users\svans\appdata\local\programs\python\python314\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\svans\appdata\local\programs\python\python314\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\svans\appdata\local\programs\python\python314\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\svans\appdata\local\programs\python\python314\lib\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\svans\appdata\local\programs\python\python314\lib\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\svans\appdata\local\programs\python\python314\lib\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\svans\appdata\local\programs\python\python314\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\svans\appdata\local\programs\python\python314\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.5.0)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\svans\appdata\local\programs\python\python314\lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\svans\appdata\local\programs\python\python314\lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.23)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\svans\appdata\local\programs\python\python314\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (0.6.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import config
from google import genai

client = genai.Client(api_key=config.GEMINI_API_KEY)

response = client.models.generate_content(
    model=config.GEMINI_MODEL,
    contents="Say: Gemini connection successful."
)

print(response.text)
# Out:
# Gemini connection successful.
